# %%
import pandas as pd
import matplotlib.pyplot as plt

food = pd.read_csv('C:\\Users\\preet\\Downloads\\Hayome\\FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='ISO-8859-1')
print(food)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
## .head(int rows) allows to see the first data from the given amt of rows. 
food.head(3)
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
#
#                          Element             Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes     1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity      1000 tonnes      0.0      0.0      0.0
# 2  Food supply (kcal/capita/day)  kcal/capita/day   3377.0   3379.0   3372.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0
# 2   3341.0   3322.0

# %%
## .tail(int rows) allows to see the last data from the given amt of rows. 
food.tail(3)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60940           Food supply (kcal/capita/day)  kcal/capita/day   3.00   4.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day   0.10   0.11
# 60942      Fat supply quantity (g/capita/day)     g/capita/day   0.04   0.05
#
#        Y2016  Y2017  Y2018
# 60940   3.00   1.00   1.00
# 60941   0.08   0.04   0.04
# 60942   0.03   0.02   0.01

# %%
## .dtypes identifies the data types of the dataframe
food.dtypes
# Out:
# Area Code         int64
# Area             object
# Item Code         int64
# Item             object
# Element Code      int64
# Element          object
# Unit             object
# Y2014           float64
# Y2015           float64
# Y2016           float64
# Y2017           float64
# Y2018           float64
# dtype: object

# %%
## read_* methods are used to convert data into panda data frames
## to_* methods are used to revert pandas dataframes back into data format. Ex. Excel or csv

# %%
# .info() to get a general summary of the data
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
# Get specific info from the dataframe by tranfering those values to a variable
area = food["Area"]
area.head()
# Out:
# 0    Algeria
# 1    Algeria
# 2    Algeria
# 3    Algeria
# 4    Algeria
# Name: Area, dtype: object

# %%
#.shape outputs (rows, colums)
# .isin([]) checks if stuff is equal to the stuff in the parenthesis
food["Item"].isin(["Grand Total", "Population"])
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 60938    False
# 60939    False
# 60940    False
# 60941    False
# 60942    False
# Name: Item, Length: 60943, dtype: bool

# %%
#Specific outputs
#.loc[] for broad outputs
#.iloc[rows, colums] for specific or numbered outputs
food.loc[food["Element Code"] > 800]
food.iloc[3:10, 2:18]
# Out:
#    Item Code              Item  Element Code  \
# 3       2901       Grand Total           674
# 4       2901       Grand Total           684
# 5       2903  Vegetal Products           664
# 6       2903  Vegetal Products           674
# 7       2903  Vegetal Products           684
# 8       2941   Animal Products           664
# 9       2941   Animal Products           674
#
#                                   Element             Unit    Y2014    Y2015  \
# 3  Protein supply quantity (g/capita/day)     g/capita/day    94.90    94.35
# 4      Fat supply quantity (g/capita/day)     g/capita/day    80.06    79.36
# 5           Food supply (kcal/capita/day)  kcal/capita/day  2932.00  2958.00
# 6  Protein supply quantity (g/capita/day)     g/capita/day    67.14    67.38
# 7      Fat supply quantity (g/capita/day)     g/capita/day    53.84    54.72
# 8           Food supply (kcal/capita/day)  kcal/capita/day   444.00   421.00
# ...

# %%
## PLOTTING OF DATASETS IN PYTHON WITH PANDAS AND MATPLOTLIB
